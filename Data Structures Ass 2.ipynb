# %% [raw]
# 1.	Create a list of 5 integers. Perform and print the result of the following operations: append, extend, insert, remove, pop, clear, index, count, sort, and reverse

# %%
list1=[30,40,44,55,67]

# %%
type(list1)
# Out:
# list

# %%
len(list1)
# Out:
# 5

# %%
list1.append(77)
list1
# Out:
# [30, 40, 44, 55, 67, 77]

# %%
list2=[11,22,33,66]
list1.extend(list2)
list1
# Out:
# [30, 40, 44, 55, 67, 77, 11, 22, 33, 66]

# %%
list1.insert(4,60)
list1
# Out:
# [30, 40, 44, 55, 60, 67, 77, 11, 22, 33, 66]

# %%
list1.remove(55)
list1
# Out:
# [30, 40, 44, 60, 67, 77, 11, 22, 33, 66]

# %%
list1.pop(5)
list1
# Out:
# [30, 40, 44, 60, 67, 11, 22, 33, 66]

# %%
list1.clear()
list1
# Out:
# []

# %%
list1=[30,40,44,55,67,55,30]

# %%
list1.index(44)
# Out:
# 2

# %%
list1.count(55)
# Out:
# 2

# %%
list1.sort()
list1
# Out:
# [30, 30, 40, 44, 55, 55, 67]

# %%
list1.reverse()
list1
# Out:
# [67, 55, 55, 44, 40, 30, 30]

# %% [raw]
# 2.	Create a tuple that stores 3 student names. Try changing the second name in the tuple. What happens? Explain why.

# %%
tuple1=('Rajesh','Rohan','Sumit')

# %%
tuple1[1]='Naveen'
tuple1
### as tuple is immutable, we cannot add, delete or replace any data in pre-defined tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 tuple1[1]='Naveen'
#       2 tuple1
#
# TypeError: 'tuple' object does not support item assignment

# %% [raw]
# 3.	Create a set of integers with some duplicate values. Print the set and explain the output.

# %%
set1={22,45,67,67,80,80,96}
set1

# %% [raw]
# sets stores only unique values and does not allow duplicate values. if any duplicates are found in the set, then it executes that particular data only once making it unique.

# %% [raw]
# 4.	Create a dictionary with the keys: 'name', 'age', and 'city'. Update the age and add a new key 'email'. Print the final dictionary.

# %%
import pandas as pd
import re

# %%
dict1={'name':['Arun','Sunil','Deepak','Ramesh'],'age':[22,23,24,46],'city':['Bangalore','Mysore','Bidar','Chennai']}
dict1
# Out:
# {'name': ['Arun', 'Sunil', 'Deepak', 'Ramesh'],
#  'age': [22, 23, 24, 46],
#  'city': ['Bangalore', 'Mysore', 'Bidar', 'Chennai']}

# %%
df1=pd.DataFrame(dict1)
df1
# Out:
#      name  age       city
# 0    Arun   22  Bangalore
# 1   Sunil   23     Mysore
# 2  Deepak   24      Bidar
# 3  Ramesh   46    Chennai

# %%
df1.update({'age':[12,13,14,16]})
df1
# Out:
#      name  age       city
# 0    Arun   12  Bangalore
# 1   Sunil   13     Mysore
# 2  Deepak   14      Bidar
# 3  Ramesh   16    Chennai

# %%
dict2=dict1.copy()
dict2
# Out:
# {'name': ['Arun', 'Sunil', 'Deepak', 'Ramesh'],
#  'age': [22, 23, 24, 46],
#  'city': ['Bangalore', 'Mysore', 'Bidar', 'Chennai']}

# %%
dict2.setdefault('email',['arun1@gmail.com','sun34@yahoo.com','dee4@gmail.com','rameshj@gmail.com'])
dict2
# Out:
# {'name': ['Arun', 'Sunil', 'Deepak', 'Ramesh'],
#  'age': [22, 23, 24, 46],
#  'city': ['Bangalore', 'Mysore', 'Bidar', 'Chennai'],
#  'email': ['arun1@gmail.com',
#   'sun34@yahoo.com',
#   'dee4@gmail.com',
#   'rameshj@gmail.com']}

# %%
df2=pd.DataFrame(dict2)
df2
# Out:
#      name  age       city              email
# 0    Arun   22  Bangalore    arun1@gmail.com
# 1   Sunil   23     Mysore    sun34@yahoo.com
# 2  Deepak   24      Bidar     dee4@gmail.com
# 3  Ramesh   46    Chennai  rameshj@gmail.com

# %% [raw]
# 5. Write a script that checks if a person is eligible to vote (age ≥ 18). Take age as a variable and print the appropriate message.

# %%
age=int(input('Enter the age:'))
if age<18:
    print('Not eligible to vote')
else:
    print('Eligible to vote')
# Out:
# Enter the age: 19
# Eligible to vote

# %% [raw]
# 6.	Given a 'marks' variable, print the grade:
# - 90 and above: 'A'
# - 75–89: 'B'
# - 50–74: 'C'
# - Below 50: 'Fail'

# %%
marks=int(input('Enter the marks:'))
if marks>=90:
    print('Scored grade A')
elif(marks>=75):
    print('Scored grade B')
elif(marks>=50):
    print('Scored grade C')
else: 
    print('Failed')
# Out:
# Enter the marks: 75
# Scored grade B

# %% [raw]
# 8.	Create:
# - A scalar using np.array(5)
# - A 1D array with values 1 to 5
# - A 2D array (2x3) with values from 10 to 60 in steps of 10

# %%
import numpy as np

# %%
scalar_array=np.array(5)
scalar_array
# Out:
# array(5)

# %%
scalar_array.size
# Out:
# 1

# %%
type(scalar_array)
# Out:
# numpy.ndarray

# %%
one_dim=np.array([1,2,3,4,5])
one_dim
# Out:
# array([1, 2, 3, 4, 5])

# %%
one_dim.size
# Out:
# 5

# %%
one_dim.ndim
# Out:
# 1

# %%
val=np.array(range(10,61,10))
val
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
## to create 2D array
two_d_array=(val[:3],val[3:6])
two_d_array
# Out:
# (array([10, 20, 30]), array([40, 50, 60]))

# %% [raw]
# 9.	Generate a 4x4 Numpy array of random integers between 0 and 100 using np.random.randint().

# %%
two_dim=np.random.randint(0,101,16).reshape(4,4)
two_dim
# Out:
# array([[48, 71, 15, 33],
#        [ 3, 65, 49, 10],
#        [12, 57, 56, 10],
#        [36, 15, 48, 78]], dtype=int32)

# %% [raw]
# 10.	Create a 2D numpy array of shape (3x3). Convert it into a pandas DataFrame and add column names: 'A', 'B', 'C'.

# %%
two_d_arr=np.array([[2,3,4],[6,7,8],[10,17,19]])
two_d_arr
# Out:
# array([[ 2,  3,  4],
#        [ 6,  7,  8],
#        [10, 17, 19]])

# %%
new_arr=pd.DataFrame(two_d_arr)
new_arr
# Out:
#     0   1   2
# 0   2   3   4
# 1   6   7   8
# 2  10  17  19

# %%
df = pd.DataFrame(two_d_arr, columns=['A', 'B', 'C'])
df
# Out:
#     A   B   C
# 0   2   3   4
# 1   6   7   8
# 2  10  17  19

# %% [raw]
# 11.	Create a small DataFrame manually with 10 rows and columns: 'Name', 'Age', 'City', and 'Salary'. Then:
# - Use .info(), .describe()
# - Select 'Name' and 'City' columns
# - Drop 'City' column
# - Fill any missing values in 'Salary' column with the mean
# - Remove any duplicate rows

# %%
dict1={'Name':['A','B','C','D','E','F','G','H','I','J'],'Age':[22,24,26,28,24,25,27,23,21,30],
       'City':['Bangalore','Bidar','Chennai','Delhi','Mumbai','Pune','Jaipur','Gwalior','Pune','Bidar'],
       'Salary':[2000,1000,4000,None,4000,3000,None,5000,1500,3000]}
dict1
# Out:
# {'Name': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'],
#  'Age': [22, 24, 26, 28, 24, 25, 27, 23, 21, 30],
#  'City': ['Bangalore',
#   'Bidar',
#   'Chennai',
#   'Delhi',
#   'Mumbai',
#   'Pune',
#   'Jaipur',
#   'Gwalior',
#   'Pune',
#   'Bidar'],
#  'Salary': [2000, 1000, 4000, None, 4000, 3000, None, 5000, 1500, 3000]}

# %%
df=pd.DataFrame(dict1)
df
# Out:
#   Name  Age       City  Salary
# 0    A   22  Bangalore  2000.0
# 1    B   24      Bidar  1000.0
# 2    C   26    Chennai  4000.0
# 3    D   28      Delhi     NaN
# 4    E   24     Mumbai  4000.0
# 5    F   25       Pune  3000.0
# 6    G   27     Jaipur     NaN
# 7    H   23    Gwalior  5000.0
# 8    I   21       Pune  1500.0
# 9    J   30      Bidar  3000.0

# %%
df.loc[7]=['A', 22,'Bangalore',2000]
df
# Out:
#   Name  Age       City  Salary
# 0    A   22  Bangalore  2000.0
# 1    B   24      Bidar  1000.0
# 2    C   26    Chennai  4000.0
# 3    D   28      Delhi     NaN
# 4    E   24     Mumbai  4000.0
# 5    F   25       Pune  3000.0
# 6    G   27     Jaipur     NaN
# 7    A   22  Bangalore  2000.0
# 8    I   21       Pune  1500.0
# 9    J   30      Bidar  3000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     10 non-null     int64
#  2   City    10 non-null     object
#  3   Salary  8 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 452.0+ bytes

# %%
df[['Name','City']]
# Out:
#   Name       City
# 0    A  Bangalore
# 1    B      Bidar
# 2    C    Chennai
# 3    D      Delhi
# 4    E     Mumbai
# 5    F       Pune
# 6    G     Jaipur
# 7    A  Bangalore
# 8    I       Pune
# 9    J      Bidar

# %%
df.drop(columns='City')
# Out:
#   Name  Age  Salary
# 0    A   22  2000.0
# 1    B   24  1000.0
# 2    C   26  4000.0
# 3    D   28     NaN
# 4    E   24  4000.0
# 5    F   25  3000.0
# 6    G   27     NaN
# 7    A   22  2000.0
# 8    I   21  1500.0
# 9    J   30  3000.0

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       0
# City      0
# Salary    2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
sal_mean=df['Salary'].mean()
sal_mean
# Out:
# np.float64(2562.5)

# %%
new_Sal=df.fillna(sal_mean, inplace=True)
new_Sal

# %%
df.drop_duplicates()
# Out:
#   Name  Age       City  Salary
# 0    A   22  Bangalore  2000.0
# 1    B   24      Bidar  1000.0
# 2    C   26    Chennai  4000.0
# 3    D   28      Delhi  2562.5
# 4    E   24     Mumbai  4000.0
# 5    F   25       Pune  3000.0
# 6    G   27     Jaipur  2562.5
# 8    I   21       Pune  1500.0
# 9    J   30      Bidar  3000.0
