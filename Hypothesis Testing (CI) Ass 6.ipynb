# %% [raw]
# Assignment Tasks
# a. Build 99% Confidence Interval Using Sample Standard Deviation
# Assuming the sample is representative of the population, construct a 99% confidence interval for the mean number of characters printed before the print-head fails using the sample standard deviation. Explain the steps you take and the rationale behind using the t-distribution for this task.
# b. Build 99% Confidence Interval Using Known Population Standard Deviation
# If it were known that the population standard deviation is 0.2 million characters, construct a 99% confidence interval for the mean number of characters printed before failure.

# %%
import scipy.stats as stats
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# ##Assuming data is normally distributed
# given:
# a) n=15
# CI=99%
# alpha=1%
#
# ## As n is less than 30 and value of standard deviation is not given, we perform t_test here
# first we find th value of standard deviation of the given sample using std() function

# %%
df=[1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29]

# %%
### using the given data, the sample mean(x_bar) and std_dev are calculated
x_bar=np.mean(df)
x_bar
# Out:
# np.float64(1.2386666666666666)

# %%
sample_std_dev= np.std(df)
sample_std_dev
# Out:
# np.float64(0.18661427836285438)

# %% [markdown]
# ## T-Test

# %% [markdown]
# To perform t-test,
# we need to have 2 values:
# 1.degree of freedom
# 2.alpha/2

# %% [raw]
# to find boundary values ,find t_critical using t_table
# to find t_critical,we need 2 values:alpha/2=0.005
# degree of freedom(df)=(n-1)=15-1=14

# %%
### using t-table we can find the value od t-critival as 2.97 (or) we can use stats.t.ppf()

# %%
## area=(CI+alpha/2)=0.99+0.005=0.995
t_critical=stats.t.ppf(0.995,14)

# %%
### calculating the margin of error
std_error = sample_std_dev / np.sqrt(n)
std_error
# Out:
# np.float64(0.04818359948425667)

# %%
mar_of_error = t_critical * std_error
mar_of_error
# Out:
# np.float64(0.14343499804054372)

# %%
### finding the lower and upper bound values so as to build the confidence interval
lower_value=(x_bar-mar_of_error)
upper_value=(x_bar+mar_of_error)
print(lower_value,upper_value)
# Out:
# 1.095231668626123 1.3821016647072102

# %% [markdown]
# #### Hence we can conclude that ,99% confidence interval for the mean durability of the print-heads is (1.090, 1.387) million characters

# %% [raw]
#  b) given:
# n=15
# CI=99%
# alpha=1%
# alpha/2=0.5%
# pop_std_dev=0.2

# %%
pop_std_dev=0.2

# %% [raw]
# we have:
# x_bar=1.23 million characters
# sample_std_dev=0.186
# aplha/2=0.005

# %% [markdown]
# #### As the standard deviation of the population is known we can use the z-test to find the critical value for 99% CI

# %%
## we can find z_critical value using scipy package
from scipy.stats import norm

# %%
z_critical=stats.norm.ppf(0.995)
z_critical
# Out:
# np.float64(2.5758293035489004)

# %%
### next we find margin of error for using z_critical value

# %%
marginal_error=z_critical*(pop_std_dev/np.sqrt(n))
marginal_error
# Out:
# np.float64(0.13301525327090588)

# %% [raw]
# Hence we can say that we get z_critical approx as 2.58 and value of margin of error as 0.133
# using both of these we can find the confidence interval by finding out the lower value and uppper value

# %%
lower_value=(x_bar-marginal_error)
upper_value=(x_bar+marginal_error)
print(lower_value,upper_value)
# Out:
# 1.1056514133957607 1.3716819199375725

# %% [markdown]
# #### Therefore, we can say that 99% confidence interval for the mean durability of the print-heads is approximately (1.106, 1.372) million characters printed before failure.
# .
